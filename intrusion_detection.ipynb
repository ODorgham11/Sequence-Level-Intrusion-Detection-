# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

# Deep Learning Imports
import keras
from keras.models import Sequential
from keras.layers import Input, Dense, LSTM, Conv1D, Dropout, RepeatVector, TimeDistributed, Bidirectional, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import tensorflow as tf
import random
import os

# --- GOD MODE: FREEZE RANDOMNESS ---
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
print("Randomness frozen. Results will be reproducible.")
# Out:
# Randomness frozen. Results will be reproducible.

# %%
# 1. Load Data
print("Loading datasets...")
try:
    train_df = pd.read_csv('UNSW_NB15_training-set.csv')
    test_df = pd.read_csv('UNSW_NB15_testing-set.csv')
except FileNotFoundError:
    print("ERROR: Files not found. Please upload UNSW_NB15_training-set.csv and UNSW_NB15_testing-set.csv")

# 2. Drop ID columns
if 'id' in train_df.columns: train_df = train_df.drop('id', axis=1)
if 'id' in test_df.columns: test_df = test_df.drop('id', axis=1)

# 3. Separate Labels
y_train = train_df['label']
y_test = test_df['label']

# 4. Drop Label columns for feature processing
X_train_raw = train_df.drop(['label', 'attack_cat'], axis=1)
X_test_raw = test_df.drop(['label', 'attack_cat'], axis=1)

# 5. Combine for consistent One-Hot Encoding
combined_df = pd.concat([X_train_raw, X_test_raw], axis=0)
combined_df = pd.get_dummies(combined_df)

# 6. Split back into train and test
X_train_encoded = combined_df.iloc[:len(train_df)]
X_test_encoded = combined_df.iloc[len(train_df):]

# 7. Scale Data (MinMax)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_test_scaled = scaler.transform(X_test_encoded)

# Convert to float32 to save RAM
X_train_scaled = X_train_scaled.astype(np.float32)
X_test_scaled = X_test_scaled.astype(np.float32)

print("Data Loaded & Scaled.")
print(f"Training Shape: {X_train_scaled.shape}")
# Out:
# Loading datasets...
# Data Loaded & Scaled.
# Training Shape: (82332, 196)

# %%
# --- PILLAR 1: OPTIMAL DATA VIEW ---
TIME_STEPS = 10  # Window Size

def create_sequences(data, labels, time_steps=TIME_STEPS):
    sequences = []
    seq_labels = []
    for i in range(len(data) - time_steps):
        sequences.append(data[i:(i + time_steps)])
        seq_labels.append(labels.iloc[i + time_steps])
    return np.array(sequences), np.array(seq_labels)

print(f"Creating sequences with {TIME_STEPS} steps...")
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train, TIME_STEPS)
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test, TIME_STEPS)

# FILTER: Train ONLY on Normal traffic (Label = 0)
X_train_normal = X_train_seq[y_train_seq == 0]

print(f"Total Training Sequences: {X_train_seq.shape}")
print(f"Normal Training Sequences (used for Autoencoder): {X_train_normal.shape}")
# Out:
# Creating sequences with 10 steps...
# Total Training Sequences: (82322, 10, 196)
# Normal Training Sequences (used for Autoencoder): (36990, 10, 196)

# %%
n_features = X_train_seq.shape[2]

# --- PILLAR 2: ROBUST ARCHITECTURE ---
model = Sequential([
    Input(shape=(TIME_STEPS, n_features)),

    # 1. Feature Extraction (CNN)
    # 128 filters to catch more patterns
    Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(), # Stabilizes math
    Dropout(0.2),

    # 2. Context Understanding (Encoder)
    # Bidirectional lets it see "Future" context
    Bidirectional(LSTM(64, activation='tanh', return_sequences=False)),
    
    # 3. Latent Space (Bottleneck)
    RepeatVector(TIME_STEPS),

    # 4. Reconstruction (Decoder)
    Bidirectional(LSTM(64, activation='tanh', return_sequences=True)),
    Dropout(0.2),

    # 5. Output Layer
    TimeDistributed(Dense(n_features))
])

# Slower learning rate for precision
opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss='mse')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 10, 128)        │        75,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 10, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector (RepeatVector)    │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 10, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 10, 196)        │        25,284 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 298,820 (1.14 MB)
#  Trainable params: 298,564 (1.14 MB)
#  Non-trainable params: 256 (1.00 KB)

# %%
# --- PILLAR 3: SMART TRAINING ---

# 1. Save the BEST weights (not the last ones)
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=1)

# 2. Stop if no improvement for 5 epochs
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 3. Slow down learning rate if stuck
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.00001)

print("Starting Training...")
history = model.fit(
    X_train_normal, X_train_normal,
    epochs=60,           # High ceiling, EarlyStopping will cut it short
    batch_size=64,
    validation_split=0.1,
    shuffle=True,
    callbacks=[checkpoint, early_stop, reduce_lr],
    verbose=1
)

# Plot Training History
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Training vs Validation Loss")
plt.legend()
plt.show()
# Out:
# Starting Training...
# Epoch 1/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0246
# Epoch 1: val_loss improved from None to 0.00764, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 43s 57ms/step - loss: 0.0171 - val_loss: 0.0076 - learning_rate: 1.0000e-04
# Epoch 2/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0107
# Epoch 2: val_loss improved from 0.00764 to 0.00655, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 40s 56ms/step - loss: 0.0103 - val_loss: 0.0065 - learning_rate: 1.0000e-04
# Epoch 3/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0094
# Epoch 3: val_loss improved from 0.00655 to 0.00616, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 28s 54ms/step - loss: 0.0092 - val_loss: 0.0062 - learning_rate: 1.0000e-04
# Epoch 4/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0086
# Epoch 4: val_loss improved from 0.00616 to 0.00587, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 29s 55ms/step - loss: 0.0085 - val_loss: 0.0059 - learning_rate: 1.0000e-04
# Epoch 5/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0082
# Epoch 5: val_loss improved from 0.00587 to 0.00573, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - loss: 0.0081 - val_loss: 0.0057 - learning_rate: 1.0000e-04
# Epoch 6/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0080
# Epoch 6: val_loss improved from 0.00573 to 0.00563, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 27s 52ms/step - loss: 0.0079 - val_loss: 0.0056 - learning_rate: 1.0000e-04
# Epoch 7/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0078
# Epoch 7: val_loss improved from 0.00563 to 0.00554, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 15s 29ms/step - loss: 0.0077 - val_loss: 0.0055 - learning_rate: 1.0000e-04
# Epoch 8/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0076
# Epoch 8: val_loss improved from 0.00554 to 0.00544, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 18s 34ms/step - loss: 0.0075 - val_loss: 0.0054 - learning_rate: 1.0000e-04
# Epoch 9/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0073
# Epoch 9: val_loss improved from 0.00544 to 0.00530, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - loss: 0.0073 - val_loss: 0.0053 - learning_rate: 1.0000e-04
# Epoch 10/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0071
# Epoch 10: val_loss improved from 0.00530 to 0.00515, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - loss: 0.0070 - val_loss: 0.0051 - learning_rate: 1.0000e-04
# Epoch 11/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0068
# Epoch 11: val_loss improved from 0.00515 to 0.00496, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 43s 45ms/step - loss: 0.0067 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Epoch 12/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0066
# Epoch 12: val_loss improved from 0.00496 to 0.00476, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 41s 45ms/step - loss: 0.0065 - val_loss: 0.0048 - learning_rate: 1.0000e-04
# Epoch 13/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0064
# Epoch 13: val_loss improved from 0.00476 to 0.00461, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - loss: 0.0064 - val_loss: 0.0046 - learning_rate: 1.0000e-04
# Epoch 14/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0062
# Epoch 14: val_loss improved from 0.00461 to 0.00446, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - loss: 0.0062 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 15/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0060
# Epoch 15: val_loss improved from 0.00446 to 0.00431, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - loss: 0.0060 - val_loss: 0.0043 - learning_rate: 1.0000e-04
# Epoch 16/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0058
# Epoch 16: val_loss improved from 0.00431 to 0.00413, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - loss: 0.0058 - val_loss: 0.0041 - learning_rate: 1.0000e-04
# Epoch 17/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0055
# Epoch 17: val_loss improved from 0.00413 to 0.00394, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 23s 45ms/step - loss: 0.0054 - val_loss: 0.0039 - learning_rate: 1.0000e-04
# Epoch 18/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0052
# Epoch 18: val_loss improved from 0.00394 to 0.00378, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - loss: 0.0051 - val_loss: 0.0038 - learning_rate: 1.0000e-04
# Epoch 19/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0049
# Epoch 19: val_loss improved from 0.00378 to 0.00360, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - loss: 0.0048 - val_loss: 0.0036 - learning_rate: 1.0000e-04
# Epoch 20/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0046
# Epoch 20: val_loss improved from 0.00360 to 0.00343, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - loss: 0.0045 - val_loss: 0.0034 - learning_rate: 1.0000e-04
# Epoch 21/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0044
# Epoch 21: val_loss improved from 0.00343 to 0.00328, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - loss: 0.0043 - val_loss: 0.0033 - learning_rate: 1.0000e-04
# Epoch 22/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0041
# Epoch 22: val_loss improved from 0.00328 to 0.00314, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - loss: 0.0041 - val_loss: 0.0031 - learning_rate: 1.0000e-04
# Epoch 23/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0040
# Epoch 23: val_loss improved from 0.00314 to 0.00302, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - loss: 0.0039 - val_loss: 0.0030 - learning_rate: 1.0000e-04
# Epoch 24/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038
# Epoch 24: val_loss improved from 0.00302 to 0.00294, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - loss: 0.0038 - val_loss: 0.0029 - learning_rate: 1.0000e-04
# Epoch 25/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037
# Epoch 25: val_loss improved from 0.00294 to 0.00283, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 0.0037 - val_loss: 0.0028 - learning_rate: 1.0000e-04
# Epoch 26/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0036
# Epoch 26: val_loss improved from 0.00283 to 0.00275, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0035 - val_loss: 0.0028 - learning_rate: 1.0000e-04
# Epoch 27/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0035
# Epoch 27: val_loss improved from 0.00275 to 0.00267, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 0.0034 - val_loss: 0.0027 - learning_rate: 1.0000e-04
# Epoch 28/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0034
# Epoch 28: val_loss improved from 0.00267 to 0.00259, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0034 - val_loss: 0.0026 - learning_rate: 1.0000e-04
# Epoch 29/60
# 518/521 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033
# Epoch 29: val_loss improved from 0.00259 to 0.00253, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0033 - val_loss: 0.0025 - learning_rate: 1.0000e-04
# Epoch 30/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0032
# Epoch 30: val_loss improved from 0.00253 to 0.00245, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0032 - val_loss: 0.0025 - learning_rate: 1.0000e-04
# Epoch 31/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0032
# Epoch 31: val_loss improved from 0.00245 to 0.00239, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - loss: 0.0032 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 32/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031
# Epoch 32: val_loss improved from 0.00239 to 0.00235, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0031 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 33/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031
# Epoch 33: val_loss improved from 0.00235 to 0.00229, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0030 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 34/60
# 518/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030
# Epoch 34: val_loss improved from 0.00229 to 0.00223, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0030 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 35/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030
# Epoch 35: val_loss improved from 0.00223 to 0.00218, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0029 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 36/60
# 518/521 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029
# Epoch 36: val_loss improved from 0.00218 to 0.00214, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0029 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 37/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029
# Epoch 37: val_loss improved from 0.00214 to 0.00209, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0028 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 38/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028
# Epoch 38: val_loss improved from 0.00209 to 0.00205, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 0.0028 - val_loss: 0.0020 - learning_rate: 1.0000e-04
# Epoch 39/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028
# Epoch 39: val_loss improved from 0.00205 to 0.00201, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0028 - val_loss: 0.0020 - learning_rate: 1.0000e-04
# Epoch 40/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027
# Epoch 40: val_loss improved from 0.00201 to 0.00197, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0027 - val_loss: 0.0020 - learning_rate: 1.0000e-04
# Epoch 41/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027
# Epoch 41: val_loss improved from 0.00197 to 0.00193, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0027 - val_loss: 0.0019 - learning_rate: 1.0000e-04
# Epoch 42/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0026
# Epoch 42: val_loss improved from 0.00193 to 0.00190, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 0.0026 - val_loss: 0.0019 - learning_rate: 1.0000e-04
# Epoch 43/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0026
# Epoch 43: val_loss improved from 0.00190 to 0.00186, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0026 - val_loss: 0.0019 - learning_rate: 1.0000e-04
# Epoch 44/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0026
# Epoch 44: val_loss improved from 0.00186 to 0.00183, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0025 - val_loss: 0.0018 - learning_rate: 1.0000e-04
# Epoch 45/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0025
# Epoch 45: val_loss improved from 0.00183 to 0.00180, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0025 - val_loss: 0.0018 - learning_rate: 1.0000e-04
# Epoch 46/60
# 518/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0025
# Epoch 46: val_loss improved from 0.00180 to 0.00178, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0025 - val_loss: 0.0018 - learning_rate: 1.0000e-04
# Epoch 47/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024
# Epoch 47: val_loss improved from 0.00178 to 0.00174, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0024 - val_loss: 0.0017 - learning_rate: 1.0000e-04
# Epoch 48/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024
# Epoch 48: val_loss improved from 0.00174 to 0.00172, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 0.0024 - val_loss: 0.0017 - learning_rate: 5.0000e-05
# Epoch 49/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0024
# Epoch 49: val_loss improved from 0.00172 to 0.00170, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - loss: 0.0024 - val_loss: 0.0017 - learning_rate: 5.0000e-05
# Epoch 50/60
# 518/521 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0024
# Epoch 50: val_loss improved from 0.00170 to 0.00168, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0023 - val_loss: 0.0017 - learning_rate: 5.0000e-05
# Epoch 51/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023
# Epoch 51: val_loss improved from 0.00168 to 0.00167, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0023 - val_loss: 0.0017 - learning_rate: 5.0000e-05
# Epoch 52/60
# 518/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023
# Epoch 52: val_loss improved from 0.00167 to 0.00165, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0023 - val_loss: 0.0017 - learning_rate: 2.5000e-05
# Epoch 53/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023
# Epoch 53: val_loss improved from 0.00165 to 0.00165, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0023 - val_loss: 0.0016 - learning_rate: 2.5000e-05
# Epoch 54/60
# 518/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023
# Epoch 54: val_loss improved from 0.00165 to 0.00163, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0023 - val_loss: 0.0016 - learning_rate: 2.5000e-05
# Epoch 55/60
# 520/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023
# Epoch 55: val_loss improved from 0.00163 to 0.00163, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0023 - val_loss: 0.0016 - learning_rate: 1.2500e-05
# Epoch 56/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023
# Epoch 56: val_loss improved from 0.00163 to 0.00163, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0023 - val_loss: 0.0016 - learning_rate: 1.2500e-05
# Epoch 57/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0023
# Epoch 57: val_loss improved from 0.00163 to 0.00162, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 49s 94ms/step - loss: 0.0023 - val_loss: 0.0016 - learning_rate: 1.2500e-05
# Epoch 58/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0023
# Epoch 58: val_loss improved from 0.00162 to 0.00162, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - loss: 0.0023 - val_loss: 0.0016 - learning_rate: 1.0000e-05
# Epoch 59/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023
# Epoch 59: val_loss improved from 0.00162 to 0.00162, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0023 - val_loss: 0.0016 - learning_rate: 1.0000e-05
# Epoch 60/60
# 519/521 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023
# Epoch 60: val_loss improved from 0.00162 to 0.00161, saving model to best_model.keras
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0023 - val_loss: 0.0016 - learning_rate: 1.0000e-05

# %%
# 1. Load Best Weights (Just in case)
# model.load_weights('best_model.keras') 

# 2. Predict in Batches (Safe for RAM)
print("Predicting Test Data...")
X_test_pred = model.predict(X_test_seq)

test_mae_loss = []
BATCH_SIZE = 1000
print("Calculating Reconstruction Error...")
for i in range(0, len(X_test_seq), BATCH_SIZE):
    batch_true = X_test_seq[i : i + BATCH_SIZE]
    batch_pred = X_test_pred[i : i + BATCH_SIZE]
    
    # Mean Absolute Error
    batch_error = np.mean(np.abs(batch_pred - batch_true), axis=1)
    batch_error = np.mean(batch_error, axis=1)
    test_mae_loss.extend(batch_error)

test_mae_loss = np.array(test_mae_loss)

# 3. AUTOMATIC THRESHOLD FINDER
print("\nScanning for optimal threshold (maximizing F1 Score)...")
thresholds = np.linspace(np.min(test_mae_loss), np.max(test_mae_loss), 100)
best_f1 = 0
best_thresh = 0

for thresh in thresholds:
    preds = (test_mae_loss > thresh).astype(int)
    score = f1_score(y_test_seq, preds)
    if score > best_f1:
        best_f1 = score
        best_thresh = thresh

print(f"--- OPTIMIZATION RESULTS ---")
print(f"Best Threshold: {best_thresh:.5f}")
print(f"Best F1-Score: {best_f1:.4f}")

# 4. Generate Final Report using Best Threshold
THRESHOLD = best_thresh
predicted_labels = (test_mae_loss > THRESHOLD).astype(int)

print("\nConfusion Matrix:")
print(confusion_matrix(y_test_seq, predicted_labels))

print("\nClassification Report:")
print(classification_report(y_test_seq, predicted_labels))

# 5. Plot Final Histogram
plt.figure(figsize=(10,5))
plt.hist(test_mae_loss, bins=50, alpha=0.7, label='Reconstruction Error')
plt.axvline(THRESHOLD, color='r', linestyle='dashed', linewidth=2, label=f'Threshold ({THRESHOLD:.3f})')
plt.title("Final Error Distribution & Threshold")
plt.legend()
plt.show()
# Out:
# Predicting Test Data...
# 5480/5480 ━━━━━━━━━━━━━━━━━━━━ 31s 6ms/step
# Calculating Reconstruction Error...
#
# Scanning for optimal threshold (maximizing F1 Score)...
# --- OPTIMIZATION RESULTS ---
# Best Threshold: 0.01197
# Best F1-Score: 0.9018
#
# Confusion Matrix:
# [[ 42834  13156]
#  [ 10547 108794]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78     55990
#            1       0.89      0.91      0.90    119341
#
#     accuracy                           0.86    175331
#    macro avg       0.85      0.84      0.84    175331
# weighted avg       0.86      0.86      0.86    175331
